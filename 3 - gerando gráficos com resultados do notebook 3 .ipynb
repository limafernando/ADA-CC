# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys

sys.path.insert(1, '/home/luiz/ufpb/tcc/ADA.CC/src/')

from controller import gerador_graficos

# %%
#P1

disciplinas = ['C I', 'C VET', 'FAC I', 'IP', 'IC']
iacrs = [82.2, 86.3, 78.5, 87.2, 95.9]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P2

disciplinas = ['ALG', 'C II', 'FAC II', 'LP I', 'MTC', 'LAC']
iacrs = [54.1, 55.2, 56.9, 68, 69.1, 76.9]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P3

disciplinas = ['C III', 'CL', 'ED', 'CG', 'LP II', 'PAC', 'TC']
iacrs = [37.9, 68.9, 56.7, 38.7, 41.5, 53, 66.3]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P4

disciplinas = ['AC I', 'ING', 'C NUM', 'PDI', 'LFA', 'ORD', 'EDO', 'MOD']
iacrs = [63.9, 16, 32.4, 30.9, 54.4, 39.6, 13.5, 18.9]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P5

disciplinas = ['ADM', 'APA', 'AC II', 'BD I', 'PLP', 'SO', 'ERS']
iacrs = [40.5, 15.2, 47, 27.2, 40, 41.7, 49.3]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P6

disciplinas = ['ASI', 'COMP', 'IHM', 'IA', 'MPS', 'RC']
iacrs = [35.5, 19.2, 24.9, 27.2, 37.8, 23.5]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P7

disciplinas = ['C&S', 'ES', 'SI&D']
iacrs = [24.6, 34.7, 33.9]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)

# %%
#P8

disciplinas = ['ESP', 'TCC']
iacrs = [20.3, 20.3]

gerador_graficos.plot_distruicao_disciplinas(disciplinas, iacrs)
